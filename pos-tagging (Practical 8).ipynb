# %% [markdown]
# ## Practical 8: PoS Tagging on Text

# %%
# Definition:

# PoS tagging identifies the function of each word or character in a sentence or paragraph. PoS is performed at token level.

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
import re
from nltk import word_tokenize
from nltk import pos_tag

# %%
star_wars = """It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory 
against the evil Galactic Empire. During the battle, Rebel spies managed to steal secret plans to the 
Empire’s ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire
planet. Pursued by the Empire’s sinister agents, Princess Leia races home aboard her starship, custodian of
the stolen plans that can save her people and restore freedom to the galaxy…"""

# %%
# Cleaning the string

clean_words = re.sub("[^a-zA-Z]", " ", star_wars)
clean_words = " ".join(clean_words.split()) # remove multiple whitespaces

# %%
# tokenizing and PoS

tokens = word_tokenize(clean_words) 
pos_tokens = pos_tag(tokens) 
print(pos_tokens)
# Out:
# [('It', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('period', 'NN'), ('of', 'IN'), ('civil', 'JJ'), ('war', 'NN'), ('Rebel', 'NNP'), ('spaceships', 'VBZ'), ('striking', 'VBG'), ('from', 'IN'), ('a', 'DT'), ('hidden', 'JJ'), ('base', 'NN'), ('have', 'VBP'), ('won', 'VBN'), ('their', 'PRP$'), ('first', 'JJ'), ('victory', 'NN'), ('against', 'IN'), ('the', 'DT'), ('evil', 'JJ'), ('Galactic', 'NNP'), ('Empire', 'NNP'), ('During', 'IN'), ('the', 'DT'), ('battle', 'NN'), ('Rebel', 'NNP'), ('spies', 'NNS'), ('managed', 'VBD'), ('to', 'TO'), ('steal', 'VB'), ('secret', 'JJ'), ('plans', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('Empire', 'NNP'), ('s', 'NN'), ('ultimate', 'JJ'), ('weapon', 'IN'), ('the', 'DT'), ('DEATH', 'NNP'), ('STAR', 'NNP'), ('an', 'DT'), ('armored', 'JJ'), ('space', 'NN'), ('station', 'NN'), ('with', 'IN'), ('enough', 'JJ'), ('power', 'NN'), ('to', 'TO'), ('destroy', 'VB'), ('an', 'DT'), ('entire', 'JJ'), ('planet', 'NN'), ('Pursued', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('Empire', 'NNP'), ('s', 'NN'), ('sinister', 'NN'), ('agents', 'NNS'), ('Princess', 'NNP'), ('Leia', 'NNP'), ('races', 'VBZ'), ('home', 'NN'), ('aboard', 'IN'), ('her', 'PRP$'), ('starship', 'JJ'), ('custodian', 'NN'), ('of', 'IN'), ('the', 'DT'), ('stolen', 'VBN'), ('plans', 'NNS'), ('that', 'WDT'), ('can', 'MD'), ('save', 'VB'), ('her', 'PRP$'), ('people', 'NNS'), ('and', 'CC'), ('restore', 'NN'), ('freedom', 'NN'), ('to', 'TO'), ('the', 'DT'), ('galaxy', 'NN')]

# %%
import spacy
sp = spacy.load('en_core_web_sm')

#To see the dependency of each token on another along with the POS tag.
from spacy import displacy
sen = sp(star_wars)
displacy.render(sen, style='dep', jupyter=True, options={'distance': 85})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="afdd5c67f87941e785956890e507e89a-0" class="displacy" width="7615" height="434.5" direction="ltr" style="max-width: none; height: 434.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="135">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="220">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="220">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="305">period</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="305">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="390">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="390">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="475">civil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="475">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="560">war.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="560">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="645">Rebel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="645">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="730">spaceships,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="815">striking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="815">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="900">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="985">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="985">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1070">hidden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1070">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1155">base,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1155">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1240">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1240">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1325">won</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1410">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1495">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1495">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1580">victory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1665">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1665">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1750">against</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1835">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1835">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="1920">evil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="2005">Galactic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2005">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="2090">Empire.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="2175">During</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2175">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="2260">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2260">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="2345">battle,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2345">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="2430">Rebel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="2515">spies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2515">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="344.5">
#     <tspan class="displacy-word" fill="currentColor" x="2600">managed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">VER
